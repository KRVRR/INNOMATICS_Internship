# %%
# Installing BeautifulSoup
! pip install bs4

# %%
# Loading required libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %%
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/44.0.2403.157 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})

# %%
# Identify the URL

URL='https://www.flipkart.com/asus-celeron-dual-core-4-gb-1-tb-hdd-windows-10-home-x543ma-gq1015t-laptop/product-reviews/itmf8811674edbeb?pid=COMFSKF9UQH8RKYF&lid=LSTCOMFSKF9UQH8RKYFK8UKIL&marketplace=FLIPKART&page=1'

# %%
# Loading the WebPage in Memory using requests library
page = requests.get(URL,headers=HEADERS)
# Format the HTML code using bs4 library
soup = BeautifulSoup(page.content, "lxml")

# %%
# Check the Status Code of the Page
page.status_code
# Out:
# 200

# %%
# Extracting the HTML Code of the WebPage
htmlcode=page.content

# %%
htmlcode
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.3d34a6.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
# Review Title
Review_title = soup.find('p', attrs={'class' : "_2-N8zT"})
print(Review_title.text)
# Out:
# Simply awesome

# %%
# Review Text
Review_text = soup.find('div', attrs={'class' : "t-ZTKy"})
print(Review_text.text)
# Out:
# It's very good to this price.....I really thankful to flipkart 😊😘.... it's very good experience with flipkart.... thank you...💙READ MORE

# %%
# Review Rating
Review_rating= soup.find('div', attrs={'class' : '_3LWZlK _1BLPMq'})
print(Review_rating.text)
# Out:
# 5

# %%
# Users Location
User_city = soup.find('p', attrs={'class' : "_2mcZGG"})
print(User_city.text)
# Out:
# Certified Buyer, Shil

# %%
# Review Upvotes
Review_upvotes = soup.find('div', attrs={'class' : "_1LmwT9"})
print(Review_upvotes.text)
# Out:
# 272

# %%
# Review Downvotes
Review_downvotes = soup.find('div', attrs={'class' : "_1LmwT9 pkR4jH"})
print(Review_downvotes.text)
# Out:
# 33

# %%
# Age Of Reviews
Review_age = soup.find('div', attrs={'class' : "row _3n8db9"})
print(Review_age.text)
# Out:
# Flipkart CustomerCertified Buyer, Shil1 month ago27233PermalinkReport Abuse

# %%
# Scrapping the Web Page

Review_title = []
Review_text = []
Review_rating = []
User_city = []
Review_upvotes = []
Review_downvotes = []
Review_age = []


for i in range(1, 59):
    URL='https://www.flipkart.com/asus-celeron-dual-core-4-gb-1-tb-hdd-windows-10-home-x543ma-gq1015t-laptop/product-reviews/itmf8811674edbeb?pid=COMFSKF9UQH8RKYF&lid=LSTCOMFSKF9UQH8RKYFK8UKIL&marketplace=FLIPKART&page={}'.format(i)
    page = requests.get(URL)
    print(i,page)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all('div', attrs={'class' : 'col _2wzgFH K0kLPL'}):

        Reviewtitle = x.find('p', attrs={'class' : "_2-N8zT"})
        if Reviewtitle is None:
            Review_title.append(np.NaN)
        else:
            Review_title.append(Reviewtitle.text)

        Reviewtext = x.find('div', attrs={'class' : 't-ZTKy'})
        if Reviewtext is None:
            Review_text.append(np.NaN)
        else:
            Review_text.append(Reviewtext.text)

        Reviewrating=soup.find('div', attrs={'class' : '_3LWZlK _1BLPMq'})
        if Reviewrating is None:
            Review_rating.append(np.NaN)
        else:
            Review_rating.append(Reviewrating.text)

        Usercity = x.find('p', attrs={'class' : "_2mcZGG"})
        if Usercity is None:
            User_city.append(np.NaN)
        else:
            User_city.append(Usercity.text)
        
        ReviewUpvotes = x.find('div', attrs={'class' : "_1LmwT9"})
        if ReviewUpvotes is None:
            Review_upvotes.append(np.NaN)
        else:
            Review_upvotes.append(ReviewUpvotes.text)
            
        ReviewDownvotes = x.find('div', attrs={'class' : "_1LmwT9 pkR4jH"})
        if ReviewDownvotes is None:
            Review_downvotes.append(np.NaN)
        else:
            Review_downvotes.append(ReviewDownvotes.text)
        
        ReviewAge = x.find('div', attrs={'class' : "row _3n8db9"})
        if ReviewAge is None:
            Review_age.append(np.NaN)
        else:
            Review_age.append(ReviewAge.text)
# Out:
# 1 <Response [200]>
# 2 <Response [200]>
# 3 <Response [200]>
# 4 <Response [200]>
# 5 <Response [200]>
# 6 <Response [200]>
# 7 <Response [200]>
# 8 <Response [200]>
# 9 <Response [200]>
# 10 <Response [200]>
# 11 <Response [200]>
# 12 <Response [200]>
# 13 <Response [200]>
# 14 <Response [200]>
# 15 <Response [200]>
# 16 <Response [200]>
# 17 <Response [200]>
# 18 <Response [200]>
# 19 <Response [200]>
# 20 <Response [200]>
# 21 <Response [200]>
# 22 <Response [200]>
# 23 <Response [200]>
# 24 <Response [200]>
# 25 <Response [200]>
# 26 <Response [200]>
# 27 <Response [200]>
# 28 <Response [200]>
# 29 <Response [200]>
# 30 <Response [200]>
# 31 <Response [200]>
# 32 <Response [200]>
# 33 <Response [200]>
# 34 <Response [200]>
# 35 <Response [200]>
# 36 <Response [200]>
# 37 <Response [200]>
# 38 <Response [200]>
# 39 <Response [200]>
# 40 <Response [200]>
# 41 <Response [200]>
# 42 <Response [200]>
# 43 <Response [200]>
# 44 <Response [200]>
# 45 <Response [200]>
# ...

# %%
print(len(Review_title))
print(len(Review_text))
print(len(Review_rating))
print(len(User_city))
print(len(Review_upvotes))
print(len(Review_downvotes))
print(len(Review_age))
# Out:
# 573
# 573
# 573
# 573
# 573
# 573
# 573

# %%
URL1='https://www.flipkart.com/asus-celeron-dual-core-4-gb-1-tb-hdd-windows-10-home-x543ma-gq1015t-laptop/p/itmf8811674edbeb?pid=COMFSKF9UQH8RKYF&lid=LSTCOMFSKF9UQH8RKYFK8UKIL&marketplace=FLIPKART&spotlightTagId=BestsellerId_6bo%2Fb5g&srno=s_1_1&otracker=AS_QueryStore_OrganicAutoSuggest_1_12_sc_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_12_sc_na_na&fm=SEARCH&iid=75ad03d7-2d2d-49d5-8d21-5085b0575b81.COMFSKF9UQH8RKYF.SEARCH&ppt=sp&ppn=sp&ssid=yf5kl0kq9s0000001613640688573&qH=a5bf07ac83aca8a6'

# %%
# Loading the WebPage in Memory using requests library
page1 = requests.get(URL1,headers=HEADERS)
# Format the HTML code using bs4 library
soup1 = BeautifulSoup(page1.content, "lxml")

# %%
# Check the Status Code of the Page
page1.status_code
# Out:
# 200

# %%
# Extracting the HTML Code of the WebPage
htmlcode1=page1.content

# %%
htmlcode1
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/><link href="https://img1a.flixcart.com" rel="dns-prefetch"/><link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.3d34a6.css"/><link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_f64bb3.png" as="image"><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon"
# ...

# %%
# Product Price
Product_price = soup1.find('div', attrs={'class' : "_30jeq3 _16Jk6d"})
print(Product_price.text)
# Out:
# ₹21,990

# %%
price=[]
for i in range(1,574):
    price.append(21900)

# %%
price
# Out:
# [21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
#  21900,
# ...

# %%
# Product 
Product = soup1.find('span', attrs={'class' : "B_NuCI"})
print(Product.text)
# Out:
# Asus Celeron Dual Core - (4 GB/1 TB HDD/Windows 10 Home) X543MA-GQ1015T Laptop  (15.6 inch, Transparent Silver, 1.9 kg)

# %%
# Product Brand
Brand='Asus' 
Product_brand=[]
for i in range(1,574):
    Product_brand.append(Brand)

# %%
Product_brand
# Out:
# ['Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
#  'Asus',
# ...

# %%
# Product Model
Model='Celeron' 
Product_model=[]
for i in range(1,574):
    Product_model.append(Model)

# %%
Product_model
# Out:
# ['Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
#  'Celeron',
# ...

# %%
# Product Features
Product_features = soup1.find('div', attrs={'class' : "_2cM9lP"})
print(Product_features.text)
# Out:
# HighlightsPre-installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)

# %%
Feature=r'installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)' 
Product_feature=[]
for i in range(1,574):
    Product_feature.append(Feature)

# %%
Product_feature
# Out:
# ['installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)',
#  'installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)',
#  'installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)',
#  'installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)',
#  'installed Genuine Windows 10 OSLight Laptop without Optical Disk Drive15.6 inch HD LED Backlit Anti-glare Display (200 nits Brightness, 45% NTSC, 75% Screen-to-body Ratio)',
# ...

# %%
# Product Average Rating
Product_avg_rating = soup1.find('div', attrs={'class' : "_3LWZlK"})
print(Product_avg_rating.text)
# Out:
# 4

# %%
Product_average_rating=[]
for i in range(1,574):
    Product_average_rating.append('4.0')

# %%
Product_average_rating
# Out:
# ['4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '4.0',
# ...

# %%
# Product Category
Product_Category=[]
for i in range(1,574):
    Product_Category.append('Laptop')

# %%
Product_Category
# Out:
# ['Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
#  'Laptop',
# ...

# %%
print(len(Review_title))
print(len(Review_text))
print(len(Review_rating))
print(len(User_city))
print(len(Review_upvotes))
print(len(Review_downvotes))
print(len(Review_age))
print(len(price))
print(len(Product_brand))
print(len(Product_model))
print(len(Product_feature))
print(len(Product_average_rating))
print(len(Product_Category))
# Out:
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573
# 573

# %%
df = pd.DataFrame({'Review_title' : Review_title, 'Review_text' : Review_text, 
                   'Review_rating' : Review_rating,'Review_upvotes' : Review_upvotes, 
                   'Review_downvotes' : Review_downvotes,'User_city':User_city,
                   'Review_age' : Review_age,'price' : price, 'Product_brand' : Product_brand, 
                   'Product_name' : Product_model,'Product_feature' : Product_feature, 
                   'Product_average_rating' : Product_average_rating, 
                   'Product_Category' : Product_Category
                  })

# %%
df.head()
# Out:
#      Review_title                                        Review_text  \
# 0  Simply awesome  It's very good to this price.....I really than...
# 1   Great product  Seriously awwsm .. pls go for it  without any ...
# 2    Nice product  I am happy with this laptop. Good for basic us...
# 3     Really Nice  it's quite good ,and one important thing to do...
# 4       Wonderful  Laptop is good for this price, not too good an...
#
#   Review_rating Review_upvotes Review_downvotes                    User_city  \
# 0             5            272               33        Certified Buyer, Shil
# 1             5            145               24              Certified Buyer
# 2             5            367               97              Certified Buyer
# 3             5             20                9      Certified Buyer, Nashik
# 4             5             20                7  Certified Buyer, Uttarkashi
#
#                                           Review_age  price Product_brand  \
# ...

# %%
df.shape
# Out:
# (573, 13)

# %%
df.isnull().sum()
# Out:
# Review_title              0
# Review_text               0
# Review_rating             0
# Review_upvotes            0
# Review_downvotes          0
# User_city                 0
# Review_age                0
# price                     0
# Product_brand             0
# Product_name              0
# Product_feature           0
# Product_average_rating    0
# Product_Category          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573 entries, 0 to 572
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Review_title            573 non-null    object
#  1   Review_text             573 non-null    object
#  2   Review_rating           573 non-null    object
#  3   Review_upvotes          573 non-null    object
#  4   Review_downvotes        573 non-null    object
#  5   User_city               573 non-null    object
#  6   Review_age              573 non-null    object
#  7   price                   573 non-null    int64
#  8   Product_brand           573 non-null    object
#  9   Product_name            573 non-null    object
#  10  Product_feature         573 non-null    object
#  11  Product_average_rating  573 non-null    object
#  12  Product_Category        573 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 58.3+ KB

# %%
df.describe()
# Out:
#          price
# count    573.0
# mean   21900.0
# std        0.0
# min    21900.0
# 25%    21900.0
# 50%    21900.0
# 75%    21900.0
# max    21900.0

# %%
df.columns
# Out:
# Index(['Review_title', 'Review_text', 'Review_rating', 'Review_upvotes',
#        'Review_downvotes', 'User_city', 'Review_age', 'price', 'Product_brand',
#        'Product_name', 'Product_feature', 'Product_average_rating',
#        'Product_Category'],
#       dtype='object')

# %%
df.to_excel('Asus_Celeron.xlsx', index = False)
